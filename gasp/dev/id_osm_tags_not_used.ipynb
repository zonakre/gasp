# %%
"""
Use a file OSM to detect tags not considered in the
OSM2LULC procedure
"""

# %%
# Parameters

OSM_FILE    = r'D:\indev\OSM2LULC\id_not_used_tags\osm_15.xml'
OSM_TAG_MAP = {
    "DB"        : r'D:\xpto\gasp\gasp\osm2lulc\osmtolulc.sqlite',
    "OSM_FEAT"  : 'osm_features',
    "KEY_COL"   : "key",
    "VALUE_COL" : "value",
    "GEOM_COL"  : "geom"
}

WORKSPACE   = r'D:\indev\OSM2LULC\id_not_used_tags'

# %%
import os
from gasp.oss import get_filename
from gasp.osm2lulc.utils import osm_to_sqdb
from gasp.fm.sqLite import sqlq_to_df
from gasp.cpu.gdl.anls.exct import sel_by_attr

# %%
#sqdb = osm_to_sqdb(OSM_FILE, os.path.join(WORKSPACE, get_filename(OSM_FILE) + '.sqlite'))
sqdb = r'D:\indev\OSM2LULC\id_not_used_tags\osm_15.sqlite'

# %%
# Get Features we are considering

ourOSMFeatures = sqlq_to_df(OSM_TAG_MAP["DB"], (
    "SELECT {key} AS key_y, {value} AS value_y, {geom} AS geom_y "
    "FROM {tbl}"
).format(
    key=OSM_TAG_MAP["KEY_COL"], value=OSM_TAG_MAP["VALUE_COL"],
    geom=OSM_TAG_MAP["GEOM_COL"], tbl=OSM_TAG_MAP["OSM_FEAT"]
))

# %%
# Get Features in File

TABLES_TAGS = {
    'points'        : ['highway', 'man_made', 'building'],
    'lines'         : ['highway', 'waterway', 'aerialway', 'barrier',
                      'man_made', 'railway'],
    'multipolygons' : ['aeroway', 'amenity', 'barrier', 'building',
                      'landuse', 'leisure', 'man_made', 'military',
                      'natural', 'office', 'waterway', 'power',
                      'railway', 'sport', 'tourism']
}

Qs = [
    " UNION ALL ".join([(
        "SELECT '{keycol}' AS key, {keycol} AS value, "
        "'{geomtype}' AS geom FROM {tbl} WHERE "
        "{keycol} IS NOT NULL"
    ).format(
        keycol=c, geomtype='Point' if table == 'points' else 'Line' if table == 'lines' else 'Polygon',
        tbl=table
    ) for c in TABLES_TAGS[table]]) for table in TABLES_TAGS
]

fileOSMFeatures = sqlq_to_df(sqdb, (
    "SELECT key, value, geom FROM ({tbl}) AS foo "
    "GROUP BY key, value, geom"
).format(tbl=" UNION ALL ".join(Qs)))

# %%
print fileOSMFeatures.shape
# Out:
# (327, 3)

# %%
print ourOSMFeatures.shape
# Out:
# (450, 3)

# %%
_fileOSMFeatures = fileOSMFeatures.merge(
    ourOSMFeatures, how='outer',
    left_on=["key", "value", "geom"],
    right_on=["key_y", "value_y", "geom_y"]
)

print _fileOSMFeatures.shape
# Out:
# (621, 6)

# %%
# Select OSM Features of file without correspondence
_fileOSMFeatures["isnew"] =_fileOSMFeatures.key_y.fillna(
    value='nenhum')

newTags = _fileOSMFeatures[_fileOSMFeatures.isnew == 'nenhum']

# Convert to str
def __to_str(row):
    try:
        row[key]   = str(row.key)
        row[value] = str(row.value)
        row['not_conv'] = 0
    except:
        row['not_conv'] = 1
    
    return row

#newTags = newTags.apply(lambda x: __to_str(x), axis=1)

print newTags.shape

newTags["whr"] = newTags.key.str.encode('utf-8').astype(str) + "='" + \
    newTags.value.str.encode('utf-8').astype(str) + "'"
# Out:
# (171, 7)

# %%
print newTags.key.str.encode('utf-8').astype(str) + "='" + newTags.value.str.encode('utf-8').astype(str) + "'"
# Out:
# 0          aerialway='cable_car'
# 1          aerialway='drag_lift'
# 2              aerialway='goods'
# 3            aeroway='aerodrome'
# 4               aeroway='hangar'
# 5              aeroway='helipad'
# 6               aeroway='runway'
# 7             aeroway='terminal'
# 9                  amenity='bar'
# 13           amenity='childcare'
# 19      amenity='drinking_water'
# 30           amenity='monastery'
# 31            amenity='mortuary'
# 42     amenity='public_building'
# 44          amenity='residencia'
# 47      amenity='slaughterhouse'
# 54             barrier='bollard'
# 55               barrier='chain'
# 56           barrier='city_wall'
# 57               barrier='fence'
# 58               barrier='fence'
# 59          barrier='fence;wall'
# 60                barrier='gate'
# 61          barrier='guard_rail'
# 62               barrier='hedge'
# 63      barrier='jersey_barrier'
# 64                barrier='kerb'
# 65      barrier='retaining_wall'
# 66                barrier='step'
# 67                barrier='wall'
#                  ...
# 295                sport='multi'
# 296        sport='paddle_tennis'
# 297                sport='padel'
# 298        sport='roller_hockey'
# 299                sport='rugby'
# 300         sport='rugby_league'
# 301             sport='shooting'
# 302           sport='skateboard'
# 303               sport='soccer'
# 304             sport='swimming'
# 305               sport='tennis'
# 306           sport='volleyball'
# 307         tourism='attraction'
# 308          tourism='camp_site'
# 309       tourism='caravan_site'
# 310             tourism='chalet'
# 311        tourism='guest_house'
# 312              tourism='hotel'
# 313        tourism='information'
# 314             tourism='museum'
# 315        tourism='picnic_site'
# 316         tourism='theme_park'
# 317             waterway='canal'
# 318               waterway='dam'
# 319               waterway='dam'
# 320             waterway='ditch'
# 321             waterway='drain'
# 323         waterway='riverbank'
# 326              waterway='weir'
# 327               waterway='yes'
# Length: 171, dtype: object

# %%
#display(newTags, raw=True)
import pandas

with pandas.option_context('display.max_rows', None, 'display.max_columns', None):
    print newTags[newTags['not_conv'] == 1]
# Out:
#            key                    value     geom  key_y  value_y  geom_y  \
# 0    aerialway                cable_car     Line    NaN      NaN     NaN
# 1    aerialway                drag_lift     Line    NaN      NaN     NaN
# 2    aerialway                    goods     Line    NaN      NaN     NaN
# 3      aeroway                aerodrome  Polygon    NaN      NaN     NaN
# 4      aeroway                   hangar  Polygon    NaN      NaN     NaN
# 5      aeroway                  helipad  Polygon    NaN      NaN     NaN
# 6      aeroway                   runway  Polygon    NaN      NaN     NaN
# 7      aeroway                 terminal  Polygon    NaN      NaN     NaN
# 9      amenity                      bar  Polygon    NaN      NaN     NaN
# 13     amenity                childcare  Polygon    NaN      NaN     NaN
# 19     amenity           drinking_water  Polygon    NaN      NaN     NaN
# 30     amenity                monastery  Polygon    NaN      NaN     NaN
# 31     amenity                 mortuary  Polygon    NaN      NaN     NaN
# 42     amenity          public_building  Polygon    NaN      NaN     NaN
# 44     amenity               residencia  Polygon    NaN      NaN     NaN
# 47     amenity           slaughterhouse  Polygon    NaN      NaN     NaN
# 54     barrier                  bollard     Line    NaN      NaN     NaN
# 55     barrier                    chain     Line    NaN      NaN     NaN
# 56     barrier                city_wall     Line    NaN      NaN     NaN
# 57     barrier                    fence     Line    NaN      NaN     NaN
# 58     barrier                    fence  Polygon    NaN      NaN     NaN
# 59     barrier               fence;wall  Polygon    NaN      NaN     NaN
# 60     barrier                     gate     Line    NaN      NaN     NaN
# 61     barrier               guard_rail     Line    NaN      NaN     NaN
# 62     barrier                    hedge     Line    NaN      NaN     NaN
# 63     barrier           jersey_barrier     Line    NaN      NaN     NaN
# 64     barrier                     kerb  Polygon    NaN      NaN     NaN
# 65     barrier           retaining_wall     Line    NaN      NaN     NaN
# 66     barrier                     step     Line    NaN      NaN     NaN
# 67     barrier                     wall     Line    NaN      NaN     NaN
# 68     barrier                     wall  Polygon    NaN      NaN     NaN
# 69     barrier                      yes     Line    NaN      NaN     NaN
# 70    building              Clavegueres  Polygon    NaN      NaN     NaN
# 71    building               La Cabanya    Point    NaN      NaN     NaN
# 72    building                 Mas Reig    Point    NaN      NaN     NaN
# 73    building                    Sport  Polygon    NaN      NaN     NaN
# 74    building           Torre d'en Bru  Polygon    NaN      NaN     NaN
# 77    building                 basilica  Polygon    NaN      NaN     NaN
# 79    building                   castle  Polygon    NaN      NaN     NaN
# 81    building                   church    Point    NaN      NaN     NaN
# 83    building               commercial    Point    NaN      NaN     NaN
# 90    building      farm_auxiliary;farm  Polygon    NaN      NaN     NaN
# 91    building                 farmyard  Polygon    NaN      NaN     NaN
# 92    building                   garage    Point    NaN      NaN     NaN
# 94    building                  garages    Point    NaN      NaN     NaN
# 97    building                 hospital    Point    NaN      NaN     NaN
# 100   building                    house    Point    NaN      NaN     NaN
# 102   building                      hut    Point    NaN      NaN     NaN
# 104   building               industrial    Point    NaN      NaN     NaN
# 106   building        isolated_dwelling  Polygon    NaN      NaN     NaN
# 107   building             kindergarten  Polygon    NaN      NaN     NaN
# 108   building                 monestir  Polygon    NaN      NaN     NaN
# 109   building                   office    Point    NaN      NaN     NaN
# 111   building                   public    Point    NaN      NaN     NaN
# 117   building                   school    Point    NaN      NaN     NaN
# 120   building                     shed    Point    NaN      NaN     NaN
# 122   building                   sports  Polygon    NaN      NaN     NaN
# 124   building             storage_tank  Polygon    NaN      NaN     NaN
# 125   building                       sí  Polygon    NaN      NaN     NaN
# 131   building                warehouse    Point    NaN      NaN     NaN
# 133   building                      yes    Point    NaN      NaN     NaN
# 135   building                     yes=  Polygon    NaN      NaN     NaN
# 137    highway                 bus_stop    Point    NaN      NaN     NaN
# 139    highway                 crossing    Point    NaN      NaN     NaN
# 141    highway                   escape     Line    NaN      NaN     NaN
# 143    highway                 give_way    Point    NaN      NaN     NaN
# 144    highway            incline_steep    Point    NaN      NaN     NaN
# 146    highway                milestone    Point    NaN      NaN     NaN
# 147    highway          mini_roundabout    Point    NaN      NaN     NaN
# 149    highway        motorway_junction    Point    NaN      NaN     NaN
# 153    highway               pedestrian    Point    NaN      NaN     NaN
# 159    highway                rest_area    Point    NaN      NaN     NaN
# 164    highway             speed_camera    Point    NaN      NaN     NaN
# 166    highway                     stop    Point    NaN      NaN     NaN
# 167    highway              street_lamp    Point    NaN      NaN     NaN
# 171    highway          traffic_signals    Point    NaN      NaN     NaN
# 174    highway           turning_circle    Point    NaN      NaN     NaN
# 175    highway             turning_loop    Point    NaN      NaN     NaN
# 177    highway              via_ferrata     Line    NaN      NaN     NaN
# 182    landuse               churchyard  Polygon    NaN      NaN     NaN
# 202    landuse           traffic_island  Polygon    NaN      NaN     NaN
# 208    leisure           fitness_centre  Polygon    NaN      NaN     NaN
# 216    leisure        recreation_ground  Polygon    NaN      NaN     NaN
# 221   man_made                     adit    Point    NaN      NaN     NaN
# 222   man_made                   bridge     Line    NaN      NaN     NaN
# 223   man_made              bunker_silo     Line    NaN      NaN     NaN
# 224   man_made                  chimney    Point    NaN      NaN     NaN
# 225   man_made                  chimney  Polygon    NaN      NaN     NaN
# 226   man_made            conveyor_belt     Line    NaN      NaN     NaN
# 227   man_made                  cutline     Line    NaN      NaN     NaN
# 228   man_made                 flagpole    Point    NaN      NaN     NaN
# 229   man_made                     mast    Point    NaN      NaN     NaN
# 230   man_made       monitoring_station     Line    NaN      NaN     NaN
# 231   man_made       monitoring_station    Point    NaN      NaN     NaN
# 232   man_made                 pipeline     Line    NaN      NaN     NaN
# 233   man_made                     pole    Point    NaN      NaN     NaN
# 234   man_made                reservoir     Line    NaN      NaN     NaN
# 235   man_made        reservoir_covered     Line    NaN      NaN     NaN
# 236   man_made        reservoir_covered    Point    NaN      NaN     NaN
# 237   man_made        reservoir_covered  Polygon    NaN      NaN     NaN
# 238   man_made                     silo     Line    NaN      NaN     NaN
# 239   man_made             storage_tank     Line    NaN      NaN     NaN
# 240   man_made             storage_tank  Polygon    NaN      NaN     NaN
# 241   man_made             survey_point    Point    NaN      NaN     NaN
# 242   man_made                    tower     Line    NaN      NaN     NaN
# 243   man_made                    tower    Point    NaN      NaN     NaN
# 244   man_made         wastewater_plant     Line    NaN      NaN     NaN
# 245   man_made         wastewater_plant    Point    NaN      NaN     NaN
# 246   man_made         wastewater_plant  Polygon    NaN      NaN     NaN
# 247   man_made               water_tank     Line    NaN      NaN     NaN
# 248   man_made               water_tank  Polygon    NaN      NaN     NaN
# 249   man_made              water_tower  Polygon    NaN      NaN     NaN
# 250   man_made               water_well     Line    NaN      NaN     NaN
# 251   man_made               water_well    Point    NaN      NaN     NaN
# 252   man_made              water_works  Polygon    NaN      NaN     NaN
# 253   man_made                watermill    Point    NaN      NaN     NaN
# 254   man_made                watermill  Polygon    NaN      NaN     NaN
# 255   man_made                 windmill    Point    NaN      NaN     NaN
# 256   man_made                 windpump    Point    NaN      NaN     NaN
# 257   man_made                    works     Line    NaN      NaN     NaN
# 258   man_made                    works    Point    NaN      NaN     NaN
# 259   man_made                    works  Polygon    NaN      NaN     NaN
# 260   man_made                      yes    Point    NaN      NaN     NaN
# 261   man_made                      yes  Polygon    NaN      NaN     NaN
# 268    natural                    stone  Polygon    NaN      NaN     NaN
# 272     office  educational_institution  Polygon    NaN      NaN     NaN
# 273     office               government  Polygon    NaN      NaN     NaN
# 274     office                   lawyer  Polygon    NaN      NaN     NaN
# 275     office                      yes  Polygon    NaN      NaN     NaN
# 276      power              sub_station  Polygon    NaN      NaN     NaN
# 278      power              transformer  Polygon    NaN      NaN     NaN
# 285    railway                     tram  Polygon    NaN      NaN     NaN
# 286      sport                athletics  Polygon    NaN      NaN     NaN
# 287      sport                 baseball  Polygon    NaN      NaN     NaN
# 288      sport               basketball  Polygon    NaN      NaN     NaN
# 289      sport          beachvolleyball  Polygon    NaN      NaN     NaN
# 290      sport                   boules  Polygon    NaN      NaN     NaN
# 291      sport                 climbing  Polygon    NaN      NaN     NaN
# 292      sport                  cycling  Polygon    NaN      NaN     NaN
# 293      sport                     golf  Polygon    NaN      NaN     NaN
# 294      sport                  karting  Polygon    NaN      NaN     NaN
# 295      sport                    multi  Polygon    NaN      NaN     NaN
# 296      sport            paddle_tennis  Polygon    NaN      NaN     NaN
# 297      sport                    padel  Polygon    NaN      NaN     NaN
# 298      sport            roller_hockey  Polygon    NaN      NaN     NaN
# 299      sport                    rugby  Polygon    NaN      NaN     NaN
# 300      sport             rugby_league  Polygon    NaN      NaN     NaN
# 301      sport                 shooting  Polygon    NaN      NaN     NaN
# 302      sport               skateboard  Polygon    NaN      NaN     NaN
# 303      sport                   soccer  Polygon    NaN      NaN     NaN
# 304      sport                 swimming  Polygon    NaN      NaN     NaN
# 305      sport                   tennis  Polygon    NaN      NaN     NaN
# 306      sport               volleyball  Polygon    NaN      NaN     NaN
# 307    tourism               attraction  Polygon    NaN      NaN     NaN
# 308    tourism                camp_site  Polygon    NaN      NaN     NaN
# 309    tourism             caravan_site  Polygon    NaN      NaN     NaN
# 310    tourism                   chalet  Polygon    NaN      NaN     NaN
# 311    tourism              guest_house  Polygon    NaN      NaN     NaN
# 312    tourism                    hotel  Polygon    NaN      NaN     NaN
# 313    tourism              information  Polygon    NaN      NaN     NaN
# 314    tourism                   museum  Polygon    NaN      NaN     NaN
# 315    tourism              picnic_site  Polygon    NaN      NaN     NaN
# 316    tourism               theme_park  Polygon    NaN      NaN     NaN
# 317   waterway                    canal     Line    NaN      NaN     NaN
# 318   waterway                      dam     Line    NaN      NaN     NaN
# 319   waterway                      dam  Polygon    NaN      NaN     NaN
# 320   waterway                    ditch     Line    NaN      NaN     NaN
# 321   waterway                    drain     Line    NaN      NaN     NaN
# 323   waterway                riverbank     Line    NaN      NaN     NaN
# 326   waterway                     weir     Line    NaN      NaN     NaN
# 327   waterway                      yes     Line    NaN      NaN     NaN
#
#       isnew  not_conv
# 0    nenhum         1
# 1    nenhum         1
# 2    nenhum         1
# 3    nenhum         1
# 4    nenhum         1
# 5    nenhum         1
# 6    nenhum         1
# 7    nenhum         1
# 9    nenhum         1
# 13   nenhum         1
# 19   nenhum         1
# 30   nenhum         1
# 31   nenhum         1
# 42   nenhum         1
# 44   nenhum         1
# 47   nenhum         1
# 54   nenhum         1
# 55   nenhum         1
# 56   nenhum         1
# 57   nenhum         1
# 58   nenhum         1
# 59   nenhum         1
# 60   nenhum         1
# 61   nenhum         1
# 62   nenhum         1
# 63   nenhum         1
# 64   nenhum         1
# 65   nenhum         1
# 66   nenhum         1
# 67   nenhum         1
# 68   nenhum         1
# 69   nenhum         1
# 70   nenhum         1
# 71   nenhum         1
# 72   nenhum         1
# 73   nenhum         1
# 74   nenhum         1
# 77   nenhum         1
# 79   nenhum         1
# 81   nenhum         1
# 83   nenhum         1
# 90   nenhum         1
# 91   nenhum         1
# 92   nenhum         1
# 94   nenhum         1
# 97   nenhum         1
# 100  nenhum         1
# 102  nenhum         1
# 104  nenhum         1
# 106  nenhum         1
# 107  nenhum         1
# 108  nenhum         1
# 109  nenhum         1
# 111  nenhum         1
# 117  nenhum         1
# 120  nenhum         1
# 122  nenhum         1
# 124  nenhum         1
# 125  nenhum         1
# 131  nenhum         1
# 133  nenhum         1
# 135  nenhum         1
# 137  nenhum         1
# 139  nenhum         1
# 141  nenhum         1
# 143  nenhum         1
# 144  nenhum         1
# 146  nenhum         1
# 147  nenhum         1
# 149  nenhum         1
# 153  nenhum         1
# 159  nenhum         1
# 164  nenhum         1
# 166  nenhum         1
# 167  nenhum         1
# 171  nenhum         1
# 174  nenhum         1
# 175  nenhum         1
# 177  nenhum         1
# 182  nenhum         1
# 202  nenhum         1
# 208  nenhum         1
# 216  nenhum         1
# 221  nenhum         1
# 222  nenhum         1
# 223  nenhum         1
# 224  nenhum         1
# 225  nenhum         1
# 226  nenhum         1
# 227  nenhum         1
# 228  nenhum         1
# 229  nenhum         1
# 230  nenhum         1
# 231  nenhum         1
# 232  nenhum         1
# 233  nenhum         1
# 234  nenhum         1
# 235  nenhum         1
# 236  nenhum         1
# 237  nenhum         1
# 238  nenhum         1
# 239  nenhum         1
# 240  nenhum         1
# 241  nenhum         1
# 242  nenhum         1
# 243  nenhum         1
# 244  nenhum         1
# 245  nenhum         1
# 246  nenhum         1
# 247  nenhum         1
# 248  nenhum         1
# 249  nenhum         1
# 250  nenhum         1
# 251  nenhum         1
# 252  nenhum         1
# 253  nenhum         1
# 254  nenhum         1
# 255  nenhum         1
# 256  nenhum         1
# 257  nenhum         1
# 258  nenhum         1
# 259  nenhum         1
# 260  nenhum         1
# 261  nenhum         1
# 268  nenhum         1
# 272  nenhum         1
# 273  nenhum         1
# 274  nenhum         1
# 275  nenhum         1
# 276  nenhum         1
# 278  nenhum         1
# 285  nenhum         1
# 286  nenhum         1
# 287  nenhum         1
# 288  nenhum         1
# 289  nenhum         1
# 290  nenhum         1
# 291  nenhum         1
# 292  nenhum         1
# 293  nenhum         1
# 294  nenhum         1
# 295  nenhum         1
# 296  nenhum         1
# 297  nenhum         1
# 298  nenhum         1
# 299  nenhum         1
# 300  nenhum         1
# 301  nenhum         1
# 302  nenhum         1
# 303  nenhum         1
# 304  nenhum         1
# 305  nenhum         1
# 306  nenhum         1
# 307  nenhum         1
# 308  nenhum         1
# 309  nenhum         1
# 310  nenhum         1
# 311  nenhum         1
# 312  nenhum         1
# 313  nenhum         1
# 314  nenhum         1
# 315  nenhum         1
# 316  nenhum         1
# 317  nenhum         1
# 318  nenhum         1
# 319  nenhum         1
# 320  nenhum         1
# 321  nenhum         1
# 323  nenhum         1
# 326  nenhum         1
# 327  nenhum         1

# %%
for t in TABLES_TAGS:
    if t == 'points':
        filterDf = newTags[newTags.geom == 'Point']
    
    elif t == 'lines':
        filterDf = newTags[newTags.geom == 'Line']
    
    elif t == 'multipolygons':
        filterDf = newTags[newTags.geom == 'Polygon']
    
    shp = sel_by_attr(
        sqdb,
        u"SELECT * FROM {} WHERE {}".format(t, 
            filterDf.whr.str.cat(sep=" OR ")
        ),
        os.path.join(WORKSPACE, t + '.shp')
    )
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-11-7a2a6cfde40d> in <module>()
#      14             filterDf.whr.str.cat(sep=" OR ")
#      15         ),
# ---> 16         os.path.join(WORKSPACE, t + '.shp')
#      17     )
#
# D:\xpto\gasp\gasp\cpu\gdl\anls\exct.py in sel_by_attr(inShp, sql, outShp)
#     117
#     118     # Execute command
# --> 119     outcmd = exec_cmd(cmd)
#     120
#     121     return outShp
#
# D:\xpto\gasp\gasp\__init__.pyc in exec_cmd(cmd)
#      24
#      25     p = subprocess.Popen(cmd, shell=True,
# ---> 26                          stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#      27
#      28     out, err = p.communicate()
#
# c:\python27\arcgis10.6\lib\subprocess.pyc in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags)
#     388                                 p2cread, p2cwrite,
#     389                                 c2pread, c2pwrite,
# --> 390                                 errread, errwrite)
#     391         except Exception:
#     392             # Preserve original exception in case os.close raises.
#
# c:\python27\arcgis10.6\lib\subprocess.pyc in _execute_child(self, args, executable, preexec_fn, close_fds, cwd, env, universal_newlines, startupinfo, creationflags, shell, to_close, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite)
#     608                 startupinfo.wShowWindow = _subprocess.SW_HIDE
#     609                 comspec = os.environ.get("COMSPEC", "cmd.exe")
# --> 610                 args = '{} /c "{}"'.format (comspec, args)
#     611                 if (_subprocess.GetVersion() >= 0x80000000 or
#     612                         os.path.basename(comspec).lower() == "command.com"):
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xed' in position 882: ordinal not in range(128)
